# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import statistics
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/__init__.py:3: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/__init__.py:3: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:26: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (hashtable as _hashtable,
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:26: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   from pandas._libs import (hashtable as _hashtable,
# ...

# %% [markdown]
# # gogosing data

# %%
from konlpy.tag import Twitter
from konlpy.utils import pprint
twitter = Twitter()
from collections import Counter

pd.set_option('max_colwidth', 500)

common_front = '../../../dataset/go_0715/gogosing_' 
common_back = '.json'

def get_file(file_num):   
    file_path = common_front + str(file_num) + common_back
    json_data = open(file_path).read()
    data = json.loads(json_data)
    df_data = pd.DataFrame(data)
    return df_data


# 74번 파일이 에러가 나서 제외함
def concat_file(file_num):
    start_file = pd.DataFrame(get_file(1))
    for i in range(2,file_num+1):
        if( i == 74):
            continue
        df_tmp = pd.DataFrame(get_file(i))
        start_file = pd.concat([start_file, df_tmp])
    start_file = start_file.reset_index(drop=True)
    return start_file
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/__init__.py:3: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/__init__.py:3: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:26: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (hashtable as _hashtable,
# /usr/local/lib/python2.7/dist-packages/pandas/__init__.py:26: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   from pandas._libs import (hashtable as _hashtable,
# ...

# %%
go_data = concat_file(156)

# %%
len(go_data)
# Out:
# 772829

# %%
df = pd.DataFrame((go_data.loc[go_data['cId']=='sjj44**'])['desc'])
df
# Out:
#                                                                                                                                                        desc
# 17205                                                                                                  이제야 쓰네요 늦게 받았지만 원하는 색상입니다 아주 잘 받았습니다 많이 번창하시고 화이팅하세요
# 17206                                                                                                    이제야쓰네요 잘받았습니다 원하는 색이고 원하는 핏입니다 잘입을게요 많이 번창하세여!!화이팅
# 21805                                                                                               색이 완전 ...이쁘네요...완전 굳!!잘 입을게여~사이즈도 굳 색도 굳 배송도 굿 많은 번창하시길
# 21806                                                                          실밥이라고 해야하나요? 그게 몇몇개씩 삐져나왔는데 자르기에는 옷이 망가질까봐 걱정이고 안자르기에는 보기가 좀 그렇고..그래듀 잘 입을게여
# 21807                                                                                             아주 살짝 살짝 큰 감아 없지않아 있는데 그래도 마음에들고 배송도 빠르고 아주 좋아여 많은 번창바랍니다
# ...

# %%
#원본
from operator import sub

score = ('Term-Frequency', 'TF-IDF','Doc2Vec')
x_pos = np.arange(len(score))
number_of_reviews = [6309,4407,3399]
intersection = [5893, 4195, 2292]

plt.bar(x_pos-0.1, number_of_reviews, align='center', color=['gray'], alpha = 0.9,
        width=0.2, label='reviews')
plt.bar(x_pos+0.1, intersection, align='center', color=['gray'], alpha = 0.5,
        width=0.2, label='intersection')
plt.legend()
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('# of review', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./compare.png")
plt.show()

# %%
#맞춘거
from operator import sub

score = ('Term-Frequency', 'TF-IDF','Doc2Vec')
x_pos = np.arange(len(score))
number_of_reviews = [3327,3305,3399]
intersection = [3213, 3197, 2277]

plt.bar(x_pos-0.1, number_of_reviews, align='center', color=['gray'], alpha = 0.9,
        width=0.2, label='reviews')
plt.bar(x_pos+0.1, intersection, align='center', color=['gray'], alpha = 0.5,
        width=0.2, label='intersection')
plt.legend()
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('# of review', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./compare_gogo.png")
plt.show()

# %% [markdown]
# # Attrangs Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

from konlpy.tag import Twitter
from konlpy.utils import pprint
twitter = Twitter()
from collections import Counter

pd.set_option('max_colwidth', 500)

common_front = '../../../dataset/art_0715/artlance_' 
common_back = '.json'

def get_file(file_num):   
    file_path = common_front + str(file_num) + common_back
    json_data = open(file_path).read()
    data = json.loads(json_data)
    df_data = pd.DataFrame(data)
    return df_data

def concat_file(file_num):
    start_file = pd.DataFrame(get_file(1))
    for i in range(2,file_num+1):
        df_tmp = pd.DataFrame(get_file(i))
        start_file = pd.concat([start_file, df_tmp])
    start_file = start_file.reset_index(drop=True)
    return start_file

# %%
att_data = concat_file(56)

# %%
att_data
# Out:
#                     _id bodySize             cId  \
# 0       artlance_298371      44반       carul12**
# 1       artlance_298370      NaN      cuteseon**
# 2       artlance_298369      44반       carul12**
# 3       artlance_298368      44반       carul12**
# 4       artlance_298367      44반       carul12**
# 5       artlance_298366      NaN       dmsqo87**
# 6       artlance_298365       55         ish25**
# 7       artlance_298364       55         ish25**
# 8       artlance_298363       55         ish25**
# 9       artlance_298362      NaN         joaa4**
# 10      artlance_298361       55         ish25**
# 11      artlance_298360       66         kej03**
# 12      artlance_298359       55        yj0331**
# 13      artlance_298358       66         kej03**
# 14      artlance_298357       55        yj0331**
# 15      artlance_298356      NaN         yhm23**
# 16      artlance_298355      NaN         yhm23**
# 17      artlance_298354      NaN        jaiyun**
# ...

# %%
from operator import sub

score = ('Term-Frequency', 'TF-IDF','Doc2Vec')
x_pos = np.arange(len(score))
number_of_reviews = [2095,2176,2282]
intersection = [211, 209, 192]

plt.bar(x_pos-0.1, number_of_reviews, align='center', color=['gray'], alpha = 0.9,
        width=0.2, label='reviews')
plt.bar(x_pos+0.1, intersection, align='center', color=['gray'], alpha = 0.5,
        width=0.2, label='intersection')
plt.legend()
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('# of review', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./compare_att.png")
plt.show()

# %% [markdown]
# # sn_data

# %% [markdown]
# # precision & recall

# %% [markdown]
# gogosing

# %%
from operator import sub

score = ('Term-Frequency', 'TF-IDF','Doc2Vec')
x_pos = np.arange(len(score))
precision = [0.9657, 0.9673, 0.6699]
recall = [0.0305, 0.0304, 0.0216]

plt.bar(x_pos-0.1, precision, align='center', color=['gray'], alpha = 0.9,
        width=0.2, label='precision')
plt.bar(x_pos+0.1, recall, align='center', color=['gray'], alpha = 0.5,
        width=0.2, label='recall')
plt.legend()
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('precision & recall', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./gogosing_precision_recall.png")
plt.show()

# %% [markdown]
# attrangs

# %%
from operator import sub

score = ('Term-Frequency', 'TF-IDF','Doc2Vec')
x_pos = np.arange(len(score))
precision = [0.9512, 0.9617, 0.9496]
recall = [0.0265, 0.0272, 0.0264]

plt.bar(x_pos-0.1, precision, align='center', color=['gray'], alpha = 0.9,
        width=0.2, label='precision')
plt.bar(x_pos+0.1, recall, align='center', color=['gray'], alpha = 0.5,
        width=0.2, label='recall')
plt.legend()
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('precision & recall', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./att_precision_recall.png")
plt.show()

# %% [markdown]
# sn

# %%
from operator import sub

score = ('Term-Frequency', 'TF-IDF','Doc2Vec')
x_pos = np.arange(len(score))
precision = [0.9248, 0.8995, 0.8182]
recall = [0.0199, 0.0184, 0.0170]

plt.bar(x_pos-0.1, precision, align='center', color=['gray'], alpha = 0.9,
        width=0.2, label='precision')
plt.bar(x_pos+0.1, recall, align='center', color=['gray'], alpha = 0.5,
        width=0.2, label='recall')
plt.legend()
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('precision & recall', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./sn_precision_recall.png")
plt.show()

# %% [markdown]
# # 3개 비교

# %% [markdown]
# precision

# %%
from operator import sub

score = ('Term-Frequency', 'TF-IDF','Doc2Vec')
x_pos = np.arange(len(score))
precision_gogosing = [0.9657, 0.9673, 0.6699]
precision_att = [0.9512, 0.9617, 0.9496]
precision_sn = [0.9248, 0.8995, 0.8182]

plt.bar(x_pos-0.2, precision_gogosing, align='center', color=['gray'], alpha = 1.0,
        width=0.2)
plt.bar(x_pos, precision_att, align='center', color=['gray'], alpha = 0.6,
        width=0.2)
plt.bar(x_pos+0.2, precision_sn, align='center', color=['gray'], alpha = 0.2,
        width=0.2)
plt.legend()
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('precision', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./compare_precision.png")
plt.show()

# %% [markdown]
# recall

# %%
from operator import sub

score = ('Term-Frequency', 'TF-IDF','Doc2Vec')
x_pos = np.arange(len(score))
recall_gogosing = [0.0305, 0.0304, 0.0216]
recall_att = [0.0265, 0.0272, 0.0264]
recall_sn = [0.0199, 0.0184, 0.0170]

plt.bar(x_pos-0.2, recall_gogosing, align='center', color=['gray'], alpha = 1.0,
        width=0.2, label='G')
plt.bar(x_pos, recall_att, align='center', color=['gray'], alpha = 0.6,
        width=0.2, label='A')
plt.bar(x_pos+0.2, recall_sn, align='center', color=['gray'], alpha = 0.2,
        width=0.2, label='S')
plt.legend()
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('precision', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./compare_recall.png")
plt.show()

# %% [markdown]
# # 쇼핑몰별

# %% [markdown]
# precision

# %%
from operator import sub

score = ('A Shopping Mall', 'B Shopping Mall')
x_pos = np.arange(len(score))
precision_term_fre = [0.9657, 0.9248]
precision_tfidf = [0.9673, 0.8995]
precision_doc = [0.6699, 0.8182]

plt.bar(x_pos-0.15, precision_term_fre, align='center', color=['gray'], alpha = 1.0,
        width=0.15, label='term_frequency')
plt.bar(x_pos, precision_tfidf, align='center', color=['gray'], alpha = 0.6,
        width=0.15, label='tfidf')
plt.bar(x_pos+0.15, precision_doc, align='center', color=['gray'], alpha = 0.2,
        width=0.15, label='doc2vec')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('Precision', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./precision_shoppingmall.png")
plt.show()

# %% [markdown]
# recall

# %%
from operator import sub

score = ('A Shopping Mall', 'B Shopping Mall')
x_pos = np.arange(len(score))
recall_term_fre = [0.0305, 0.0199]
recall_tfidf = [0.0304, 0.0184]
recall_doc = [0.0216, 0.0170]

plt.bar(x_pos-0.15, recall_term_fre, align='center', color=['gray'], alpha = 1.0,
        width=0.15, label='term_frequency')
plt.bar(x_pos, recall_tfidf, align='center', color=['gray'], alpha = 0.6,
        width=0.15, label='tfidf')
plt.bar(x_pos+0.15, recall_doc, align='center', color=['gray'], alpha = 0.2,
        width=0.15, label='doc2vec')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xticks(x_pos, score, fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('Recall', fontsize=15)
ax = plt.gca()
plt.tight_layout()
plt.savefig("./recall_shoppingmall.png")
plt.show()

# %% [markdown]
# labeling

# %%
label_data = pd.read_excel('../../Hyeri/LoL/spam.xlsx')

# %%
label_data

# %%
spammer=[]
nonspammer=[]
for i in range(len(label_data)):
    if(label_data['result'][i]==1):
        spammer.append(label_data.index[i])
    elif(label_data['result'][i]==0):
        nonspammer.append(label_data.index[i])

# %%
print len(spammer)
print len(nonspammer)

# %%
print len(intersect(spammer, term_fre_go_cid))
print len(intersect(spammer, tfidf_go_cid))
print len(intersect(spammer, doc2vec_go_cid))
print len(intersect(spammer, rev2_go_cid))
