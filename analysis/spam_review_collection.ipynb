# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
from konlpy.tag import Kkma
from konlpy.utils import pprint
k = Kkma()

# %%
common_front = '../../dataset/sn_0715/stylenanda_'
common_back = '.json'

def get_file(file_num):   
    file_path = common_front + str(file_num) + common_back
    json_data = open(file_path).read()
    data = json.loads(json_data)
    df_data = pd.DataFrame(data)
    return df_data

def concat_file(file_num):
    start_file = pd.DataFrame(get_file(1))
    for i in range(2,file_num+1):
        df_tmp = pd.DataFrame(get_file(i))
        start_file = pd.concat([start_file, df_tmp])
    start_file = start_file.reset_index(drop=True)
    return start_file

sn_data = concat_file(61)

# %%
sn_data
# Out:
#                       _id bodySize          cId  \
# 0       stylenanda_544486      NaN       yj7***
# 1       stylenanda_544485      NaN       yj7***
# 2       stylenanda_544484      NaN       yj7***
# 3       stylenanda_544483      NaN       yj7***
# 4       stylenanda_544482      NaN       yj7***
# 5       stylenanda_544481        M   mi3377l***
# 6       stylenanda_544480      NaN     gbles***
# 7       stylenanda_544479      NaN     gbles***
# 8       stylenanda_544478        M     gbles***
# 9       stylenanda_544477        M     gbles***
# 10      stylenanda_544476      NaN     gbles***
# 11      stylenanda_544475      NaN     gbles***
# 12      stylenanda_544474        M     gbles***
# 13      stylenanda_544473        M     gbles***
# 14      stylenanda_544472        M     gbles***
# 15      stylenanda_544471        M     gbles***
# 16      stylenanda_544470      NaN     gbles***
# 17      stylenanda_544469        M   7847533***
# ...

# %% [markdown]
# 여러번 review를 올린 reviewer

# %%
sn_data['cId'].value_counts()[:30]
# Out:
# mkh6***         769
# gaki2***        716
# suji8***        605
# mny***          547
# rkdrudw***      507
# gbles***        501
# rhswl0***       493
# ovvvvv***       447
# b***            434
# ejc***          426
# zhang***        425
# cvn1***         408
# sunnyfunn***    407
# yjs5***         376
# helena1***      365
# sw991***        364
# kyj4***         329
# rustyap***      328
# union***        300
# h3j***          283
# sora2***        276
# ojh752***       270
# lroro***        269
# mani4***        263
# grea***         254
# ei7***          249
# ehddhk***       248
# yms0***         246
# dnjswl***       242
# sjsj3***        240
# Name: cId, dtype: int64

# %%
sn_data['cId'].value_counts()[:60].values
# Out:
# array([769, 716, 605, 547, 507, 501, 493, 447, 434, 426, 425, 408, 407,
#        376, 365, 364, 329, 328, 300, 283, 276, 270, 269, 263, 254, 249,
#        248, 246, 242, 240, 240, 239, 237, 234, 233, 233, 231, 231, 229,
#        229, 228, 228, 225, 225, 224, 223, 222, 222, 218, 217, 213, 213,
#        211, 211, 210, 204, 203, 202, 201, 199])

# %%
type(sn_data['cId'].value_counts()[:30].values)
# Out:
# numpy.ndarray

# %%
len(sn_data['cId'].value_counts().values)
# Out:
# 42917

# %% [markdown]
# 200개 이상 review를 단 reviewer

# %%
spam = sn_data.loc[sn_data['cId'].value_counts().values >= 200]

# %%
spam.shape
# Out:
# (59, 16)

# %%
spam
# Out:
#                   _id bodySize            cId  \
# 0   stylenanda_544486      NaN         yj7***
# 1   stylenanda_544485      NaN         yj7***
# 2   stylenanda_544484      NaN         yj7***
# 3   stylenanda_544483      NaN         yj7***
# 4   stylenanda_544482      NaN         yj7***
# 5   stylenanda_544481        M     mi3377l***
# 6   stylenanda_544480      NaN       gbles***
# 7   stylenanda_544479      NaN       gbles***
# 8   stylenanda_544478        M       gbles***
# 9   stylenanda_544477        M       gbles***
# 10  stylenanda_544476      NaN       gbles***
# 11  stylenanda_544475      NaN       gbles***
# 12  stylenanda_544474        M       gbles***
# 13  stylenanda_544473        M       gbles***
# 14  stylenanda_544472        M       gbles***
# 15  stylenanda_544471        M       gbles***
# 16  stylenanda_544470      NaN       gbles***
# 17  stylenanda_544469        M     7847533***
# 18  stylenanda_544468      NaN       gbles***
# ...

# %% [markdown]
# 한 product에 여러개의 댓글을 단 reviewer

# %%
sn_data_product_group = sn_data.cId.groupby(sn_data.pID).count()

# %%
sn_data_product_group.sort_values(ascending = False)
# Out:
# pID
# 96988     923
# 98923     812
# 219184    776
# 95612     753
# 95177     714
# 120835    711
# 98929     698
# 116025    641
# 208921    566
# 211680    562
# 93840     555
# 49420     551
# 211628    546
# 144388    521
# 214883    517
# 91459     509
# 92117     501
# 95180     487
# 214881    473
# 103003    466
# 95176     465
# 100825    465
# 214886    449
# 75592     438
# 207222    437
# 103000    433
# 116355    431
# 103197    425
# 144382    409
# 49428     399
#          ...
# 229688      1
# 229693      1
# 142369      1
# 142374      1
# 142434      1
# 142459      1
# 227822      1
# 227824      1
# 142446      1
# 123342      1
# 123343      1
# 123349      1
# 123356      1
# 142445      1
# 123372      1
# 142436      1
# 227832      1
# 123456      1
# 142423      1
# 229720      1
# 123423      1
# 229701      1
# 142410      1
# 227842      1
# 123434      1
# 142385      1
# 142381      1
# 123451      1
# 123454      1
# 100001      1
# ...

# %%
(sn_data.loc[sn_data['pID'] == '96988'])['desc']
# Out:
# 6         몇년전에 샀었는데 너무 오래사용해서 또 같은거 샀네요~~ 예전보다 로고부분이 자수로...
# 1203      두툼해서 찌그러트려도 망가지지않네요데일리가방이 좀 작아서 눌러넣었거든요ㅋㅋㅋ방수재질...
# 2230      원래 가지고 있던 파우치 길이 재보고상품 상세컷에 있는 사이즈 잘 보고 구매했어요 ...
# 2683                                    생각보다작지도않고 수납잘되서 좋아요
# 2819      너무 맘에 들어요><친구가 갖고있는거 보고 사야겠다고 생각했었는데세일기간에 사서 더...
# 4765      우와..♡너무 귀엽고 시크해용ㅎ사이즈도 딱 아담하고 기본적인 색조화장품은 다들어가그...
# 6379      6월 1일날 주문했는데 6월2일날 받았어요~완전 칼배송 감사합니다!!원래 쓰는 파우...
# 6934                                    배송도 빠르고 푹신푹신하고 좋네요~
# 9062      진짜 짱입니다 제가 파우치 ㅆㅓ 본것중 탑이예요이거 쓰다가 평생 죽을련답니다 감사합...
# 9258                                        생각보다 많이 들어가요 ㅎㅎ
# 10987     예전에 구매하고 몇년만에 또 구매했어요~!!!파우치 스타일난다꺼 짱이에요 진짜!일단...
# 11441     평소 핑크 파우치 큰거를 쓰고있었는데 작은거용 몇개만 넣을것을 찾다가 역시 믿사쓰!...
# 12413                       깜찍하고이쁘네요..핑크도써보고.좋아서블랙도주문했어요~~♡
# 13701                                                   조아요
# 15170            작은사이즈샀는데 평소화장하는 화장품 진짜 다 들어가요 실용성갑무난하고 이뻐요
# 16157     너무 좋아요small 주문해서 받았는데 생각보다 정말 많이 들어가서잘 가지고 다닐 ...
# ...

# %%
sn_data_product_group
# Out:
# pID
# 100001      1
# 100007     15
# 100014      4
# 100018      5
# 100025      5
# 100039      5
# 100040      5
# 100047     13
# 100059      1
# 100061     27
# 100065      7
# 100078      5
# 100079      3
# 100098      2
# 100104     18
# 100112      1
# 100117      8
# 100121      2
# 100145      4
# 100146      1
# 100152      3
# 100167     54
# 100168    144
# 100169    151
# 100172      6
# 100204      2
# 100209     46
# 100210      9
# 100214     23
# 100217      2
#          ...
# 99683       5
# 99685       6
# 99686       1
# 99692      13
# 99721       2
# 99736       6
# 99757       2
# 99778       3
# 99780       6
# 99792       6
# 99810       6
# 99817       3
# 99820      10
# 99823       7
# 99835       1
# 99847       4
# 99863      14
# 99875       4
# 99883       8
# 99893       2
# 99895       5
# 99909       2
# 99910       1
# 99919       2
# 99927       4
# 99931      23
# 99938      42
# 99940       1
# 99981      46
# 99996      28
# ...
